# %% [markdown]
# <a href="https://colab.research.google.com/github/brianzhang9/Multivariate-time-series-forecasting-using-LSTM/blob/main/%E2%80%9CValue%E5%88%86%E6%9E%90_%E6%96%B0%E7%AE%97%E7%9A%84%E5%93%8D%E5%BA%94_8_17_h1p_%E6%94%B9%E5%A4%9A%E5%B1%82%E7%A5%9E%E7%BB%8F%E5%85%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#加载对应的库
import tensorflow as tf
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
from keras.layers import Dense, GRU, Embedding, LSTM, Bidirectional,Dropout,BatchNormalization
from keras.optimizers import adam_v2
import keras.backend as K
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
import os
import random
def seed_tensorflow(seed=42):
  os.environ['PYTHONHASHSEED'] = str(seed) 
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['TF_DETERMINISTIC_OPS'] = '1' # `pip install tensorflow-determinism` first,使用与tf>2.1
seed_tensorflow(42)

# %%
# 创建训练优化器，如果loss已经收敛就早点停止
early_stopping = EarlyStopping(monitor="val_keras_r2_score",patience=200,mode="max",restore_best_weights=True)

# %%
# 计算R2分数，用来评价模型
def keras_r2_score(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - SS_res / (SS_tot + K.epsilon())

# %%
# 加载数据
data = pd.read_csv("计算结果-滤波后-完整(响应)-新差分1.csv")
data
# Out:
#      timestamp        Rz        Rg        Uc       Fri       Miu      h1-p  \
# 0         0.12  0.000000  0.000000  0.000000 -0.024559  0.009421  0.000283
# 1         0.24  0.000000  0.000000  0.000000  0.021126  0.002344 -0.000070
# 2         0.36  0.000000  0.000000  0.000000  0.015652  0.000831 -0.000025
# 3         0.48  0.000000  0.000000  0.000000  0.028614  0.000635 -0.000004
# 4         0.60  0.000000  0.000000  0.000000  0.012329  0.000701 -0.000004
# ..         ...       ...       ...       ...       ...       ...       ...
# 991     119.04  0.026442 -0.004226  0.009653  0.002468  0.000030 -0.000007
# 992     119.16 -0.027272 -0.043435 -0.008328 -0.003570  0.000011  0.000002
# 993     119.28  0.051794 -0.032891  0.017196  0.001694  0.000130 -0.000004
# 994     119.40  0.051535 -0.078209  0.011716 -0.001355  0.000199  0.000026
# 995     119.52 -0.046883  0.074120 -0.011389 -0.007516 -0.000140 -0.000009
#
#          h1-b      h2-p      h2-b      z1-p      z1-b      z2-p      z2-b
# 0    0.002467  0.000428  0.000095  0.000688 -0.002265  0.001761 -0.007287
# 1   -0.002502  0.000117  0.000022  0.000650 -0.001237  0.000528 -0.001089
# 2   -0.000934  0.000013 -0.000030  0.000369 -0.000586  0.000232 -0.000302
# 3   -0.000568 -0.000090 -0.000129  0.000515 -0.000731  0.000038 -0.000344
# 4   -0.000191 -0.000052 -0.000072  0.000274 -0.000476  0.000099 -0.000266
# ..        ...       ...       ...       ...       ...       ...       ...
# 991 -0.000003 -0.000060 -0.000040  0.000082 -0.000034 -0.000027 -0.000077
# 992  0.000002  0.000089  0.000040 -0.000133  0.000058  0.000099  0.000053
# 993 -0.000009 -0.000043 -0.000036  0.000052 -0.000013 -0.000091 -0.000042
# 994 -0.000003  0.000018  0.000019 -0.000016  0.000022 -0.000100  0.000247
# 995 -0.000010  0.000222  0.000059 -0.000334  0.000157  0.000132  0.000146
#
# [996 rows x 14 columns]

# %%
# 查看数据信息
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  996 non-null    float64
#  1   Rz         996 non-null    float64
#  2   Rg         996 non-null    float64
#  3   Uc         996 non-null    float64
#  4   Fri        996 non-null    float64
#  5   Miu        996 non-null    float64
#  6   h1-p       996 non-null    float64
#  7   h1-b       996 non-null    float64
#  8   h2-p       996 non-null    float64
#  9   h2-b       996 non-null    float64
#  10  z1-p       996 non-null    float64
#  11  z1-b       996 non-null    float64
#  12  z2-p       996 non-null    float64
#  13  z2-b       996 non-null    float64
# dtypes: float64(14)
# memory usage: 109.1 KB

# %%
# 加载划分训练集测试集的数据
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
feature_cols = ["Uc","Rg","Rz","Fri","Miu"]
target_col = "h1-p"

# %%
# 处理模型输入和输出
features = data.loc[:,feature_cols].values
targets = data.loc[:,target_col].values[:,np.newaxis]

# %%
# 划分训练集和测试集合，这里不随机打乱，后续要计算根据时间的特征表现
X_train, X_test, y_train, y_test = train_test_split(features,targets,test_size=0.2,shuffle=False)

# %%
# 对数据进行归一化
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)[:,np.newaxis,:]
X_test = scaler.transform(X_test)[:,np.newaxis,:]
y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train)
y_test = y_scaler.transform(y_test)

# %%
# 创建模型
model = Sequential()
#model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))


model.add(LSTM(400, input_shape=(X_train.shape[1:5]), return_sequences=True))

model.add(BatchNormalization())

#model.add(LSTM(100))
#, return_sequences=True

model.add(Dense(64,activation='relu'))

model.add(LSTM(400))
#model.add(Dense(64,activation='relu'))
model.add(Dense(1))
optimizer = adam_v2.Adam(learning_rate=1e-2)
model.compile(loss='mse',  optimizer = optimizer,metrics=['mse',keras_r2_score])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 1, 400)            649600
#
#  batch_normalization_7 (Batc  (None, 1, 400)           1600
#  hNormalization)
#
#  dense_16 (Dense)            (None, 1, 64)             25664
#
#  lstm_15 (LSTM)              (None, 400)               744000
#
#  dense_17 (Dense)            (None, 1)                 401
#
# =================================================================
# Total params: 1,421,265
# Trainable params: 1,420,465
# Non-trainable params: 800
# _________________________________________________________________

# %%
# 训练模型
history = model.fit(X_train,y_train,batch_size=128,epochs=1000,validation_data=(X_test,y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 6s 210ms/step - loss: 1.3413 - mse: 1.3413 - keras_r2_score: -0.3541 - val_loss: 0.0724 - val_mse: 0.0724 - val_keras_r2_score: -0.3199
# Epoch 2/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.6027 - mse: 0.6027 - keras_r2_score: 0.2176 - val_loss: 0.0634 - val_mse: 0.0634 - val_keras_r2_score: -0.1609
# Epoch 3/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.4352 - mse: 0.4352 - keras_r2_score: 0.3944 - val_loss: 0.0581 - val_mse: 0.0581 - val_keras_r2_score: -0.0597
# Epoch 4/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.4431 - mse: 0.4431 - keras_r2_score: 0.5491 - val_loss: 0.0614 - val_mse: 0.0614 - val_keras_r2_score: -0.1143
# Epoch 5/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2747 - mse: 0.2747 - keras_r2_score: 0.7040 - val_loss: 0.0520 - val_mse: 0.0520 - val_keras_r2_score: 0.0561
# Epoch 6/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2106 - mse: 0.2106 - keras_r2_score: 0.7385 - val_loss: 0.0523 - val_mse: 0.0523 - val_keras_r2_score: 0.0443
# Epoch 7/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1859 - mse: 0.1859 - keras_r2_score: 0.8038 - val_loss: 0.0520 - val_mse: 0.0520 - val_keras_r2_score: 0.0551
# Epoch 8/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2159 - mse: 0.2159 - keras_r2_score: 0.7612 - val_loss: 0.0575 - val_mse: 0.0575 - val_keras_r2_score: -0.0519
# Epoch 9/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2523 - mse: 0.2523 - keras_r2_score: 0.6680 - val_loss: 0.0575 - val_mse: 0.0575 - val_keras_r2_score: -0.0411
# Epoch 10/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.2663 - mse: 0.2663 - keras_r2_score: 0.6446 - val_loss: 0.0592 - val_mse: 0.0592 - val_keras_r2_score: -0.0799
# Epoch 11/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1685 - mse: 0.1685 - keras_r2_score: 0.6500 - val_loss: 0.0573 - val_mse: 0.0573 - val_keras_r2_score: -0.0490
# Epoch 12/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2290 - mse: 0.2290 - keras_r2_score: 0.7268 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0671
# Epoch 13/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1849 - mse: 0.1849 - keras_r2_score: 0.7806 - val_loss: 0.0515 - val_mse: 0.0515 - val_keras_r2_score: 0.0515
# Epoch 14/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2073 - mse: 0.2073 - keras_r2_score: 0.6432 - val_loss: 0.0519 - val_mse: 0.0519 - val_keras_r2_score: 0.0341
# Epoch 15/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2332 - mse: 0.2332 - keras_r2_score: 0.7010 - val_loss: 0.0588 - val_mse: 0.0588 - val_keras_r2_score: -0.0915
# Epoch 16/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1338 - mse: 0.1338 - keras_r2_score: 0.5984 - val_loss: 0.0614 - val_mse: 0.0614 - val_keras_r2_score: -0.1267
# Epoch 17/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1534 - mse: 0.1534 - keras_r2_score: 0.8157 - val_loss: 0.0515 - val_mse: 0.0515 - val_keras_r2_score: 0.0574
# Epoch 18/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.3035 - mse: 0.3035 - keras_r2_score: 0.6413 - val_loss: 0.0514 - val_mse: 0.0514 - val_keras_r2_score: 0.0554
# Epoch 19/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3019 - mse: 0.3019 - keras_r2_score: 0.2608 - val_loss: 0.0542 - val_mse: 0.0542 - val_keras_r2_score: -9.0685e-04
# Epoch 20/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2247 - mse: 0.2247 - keras_r2_score: 0.6145 - val_loss: 0.0492 - val_mse: 0.0492 - val_keras_r2_score: 0.0876
# Epoch 21/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2161 - mse: 0.2161 - keras_r2_score: 0.6388 - val_loss: 0.0512 - val_mse: 0.0512 - val_keras_r2_score: 0.0519
# Epoch 22/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1932 - mse: 0.1932 - keras_r2_score: 0.2725 - val_loss: 0.0548 - val_mse: 0.0548 - val_keras_r2_score: -0.0159
# Epoch 23/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2711 - mse: 0.2711 - keras_r2_score: 0.5115 - val_loss: 0.0522 - val_mse: 0.0522 - val_keras_r2_score: 0.0364
# Epoch 24/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2307 - mse: 0.2307 - keras_r2_score: 0.7697 - val_loss: 0.0490 - val_mse: 0.0490 - val_keras_r2_score: 0.0970
# Epoch 25/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1999 - mse: 0.1999 - keras_r2_score: 0.6704 - val_loss: 0.0511 - val_mse: 0.0511 - val_keras_r2_score: 0.0636
# Epoch 26/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1414 - mse: 0.1414 - keras_r2_score: 0.8579 - val_loss: 0.0492 - val_mse: 0.0492 - val_keras_r2_score: 0.0965
# Epoch 27/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1394 - mse: 0.1394 - keras_r2_score: 0.7263 - val_loss: 0.0489 - val_mse: 0.0489 - val_keras_r2_score: 0.0972
# Epoch 28/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1248 - mse: 0.1248 - keras_r2_score: 0.7341 - val_loss: 0.0512 - val_mse: 0.0512 - val_keras_r2_score: 0.0535
# Epoch 29/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1214 - mse: 0.1214 - keras_r2_score: 0.8777 - val_loss: 0.0496 - val_mse: 0.0496 - val_keras_r2_score: 0.0869
# Epoch 30/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1234 - mse: 0.1234 - keras_r2_score: 0.7617 - val_loss: 0.0514 - val_mse: 0.0514 - val_keras_r2_score: 0.0541
# Epoch 31/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1394 - mse: 0.1394 - keras_r2_score: 0.5059 - val_loss: 0.0494 - val_mse: 0.0494 - val_keras_r2_score: 0.0942
# Epoch 32/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1965 - mse: 0.1965 - keras_r2_score: 0.7069 - val_loss: 0.0484 - val_mse: 0.0484 - val_keras_r2_score: 0.1156
# Epoch 33/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1948 - mse: 0.1948 - keras_r2_score: 0.7223 - val_loss: 0.0471 - val_mse: 0.0471 - val_keras_r2_score: 0.1312
# Epoch 34/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1891 - mse: 0.1891 - keras_r2_score: 0.7403 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0564
# Epoch 35/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2097 - mse: 0.2097 - keras_r2_score: 0.5961 - val_loss: 0.0496 - val_mse: 0.0496 - val_keras_r2_score: 0.0857
# Epoch 36/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1754 - mse: 0.1754 - keras_r2_score: 0.5862 - val_loss: 0.0507 - val_mse: 0.0507 - val_keras_r2_score: 0.0646
# Epoch 37/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2222 - mse: 0.2222 - keras_r2_score: 0.7876 - val_loss: 0.0512 - val_mse: 0.0512 - val_keras_r2_score: 0.0666
# Epoch 38/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1729 - mse: 0.1729 - keras_r2_score: 0.8220 - val_loss: 0.0502 - val_mse: 0.0502 - val_keras_r2_score: 0.0788
# Epoch 39/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1491 - mse: 0.1491 - keras_r2_score: 0.5561 - val_loss: 0.0513 - val_mse: 0.0513 - val_keras_r2_score: 0.0553
# Epoch 40/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1908 - mse: 0.1908 - keras_r2_score: 0.6940 - val_loss: 0.0497 - val_mse: 0.0497 - val_keras_r2_score: 0.0897
# Epoch 41/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1778 - mse: 0.1778 - keras_r2_score: 0.7493 - val_loss: 0.0490 - val_mse: 0.0490 - val_keras_r2_score: 0.0958
# Epoch 42/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1310 - mse: 0.1310 - keras_r2_score: 0.7726 - val_loss: 0.0536 - val_mse: 0.0536 - val_keras_r2_score: 0.0028
# Epoch 43/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1492 - mse: 0.1492 - keras_r2_score: 0.5499 - val_loss: 0.0532 - val_mse: 0.0532 - val_keras_r2_score: 0.0078
# Epoch 44/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2283 - mse: 0.2283 - keras_r2_score: 0.7927 - val_loss: 0.0511 - val_mse: 0.0511 - val_keras_r2_score: 0.0436
# Epoch 45/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1839 - mse: 0.1839 - keras_r2_score: 0.7188 - val_loss: 0.0496 - val_mse: 0.0496 - val_keras_r2_score: 0.0780
# Epoch 46/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1990 - mse: 0.1990 - keras_r2_score: 0.4686 - val_loss: 0.0507 - val_mse: 0.0507 - val_keras_r2_score: 0.0612
# Epoch 47/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2635 - mse: 0.2635 - keras_r2_score: 0.5796 - val_loss: 0.0505 - val_mse: 0.0505 - val_keras_r2_score: 0.0645
# Epoch 48/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1560 - mse: 0.1560 - keras_r2_score: 0.6406 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0652
# Epoch 49/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1766 - mse: 0.1766 - keras_r2_score: 0.8282 - val_loss: 0.0508 - val_mse: 0.0508 - val_keras_r2_score: 0.0608
# Epoch 50/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1425 - mse: 0.1425 - keras_r2_score: 0.4301 - val_loss: 0.0495 - val_mse: 0.0495 - val_keras_r2_score: 0.0848
# Epoch 51/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2279 - mse: 0.2279 - keras_r2_score: 0.7658 - val_loss: 0.0520 - val_mse: 0.0520 - val_keras_r2_score: 0.0558
# Epoch 52/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2579 - mse: 0.2579 - keras_r2_score: 0.6269 - val_loss: 0.0558 - val_mse: 0.0558 - val_keras_r2_score: -0.0316
# Epoch 53/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2295 - mse: 0.2295 - keras_r2_score: 0.7034 - val_loss: 0.0582 - val_mse: 0.0582 - val_keras_r2_score: -0.0542
# Epoch 54/1000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.1916 - mse: 0.1916 - keras_r2_score: 0.7419 - val_loss: 0.0556 - val_mse: 0.0556 - val_keras_r2_score: -0.0187
# Epoch 55/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1556 - mse: 0.1556 - keras_r2_score: 0.6905 - val_loss: 0.0518 - val_mse: 0.0518 - val_keras_r2_score: 0.0466
# Epoch 56/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1165 - mse: 0.1165 - keras_r2_score: 0.7680 - val_loss: 0.0545 - val_mse: 0.0545 - val_keras_r2_score: 0.0094
# Epoch 57/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1095 - mse: 0.1095 - keras_r2_score: 0.8815 - val_loss: 0.0520 - val_mse: 0.0520 - val_keras_r2_score: 0.0373
# Epoch 58/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1735 - mse: 0.1735 - keras_r2_score: 0.7659 - val_loss: 0.0508 - val_mse: 0.0508 - val_keras_r2_score: 0.0602
# Epoch 59/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.3676 - mse: 0.3676 - keras_r2_score: 0.4840 - val_loss: 0.0535 - val_mse: 0.0535 - val_keras_r2_score: 0.0210
# Epoch 60/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3687 - mse: 0.3687 - keras_r2_score: 0.4846 - val_loss: 0.0568 - val_mse: 0.0568 - val_keras_r2_score: -0.0595
# Epoch 61/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1943 - mse: 0.1943 - keras_r2_score: 0.6546 - val_loss: 0.0775 - val_mse: 0.0775 - val_keras_r2_score: -0.4315
# Epoch 62/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1596 - mse: 0.1596 - keras_r2_score: 0.7203 - val_loss: 0.0611 - val_mse: 0.0611 - val_keras_r2_score: -0.1251
# Epoch 63/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1379 - mse: 0.1379 - keras_r2_score: 0.7212 - val_loss: 0.0501 - val_mse: 0.0501 - val_keras_r2_score: 0.0881
# Epoch 64/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1557 - mse: 0.1557 - keras_r2_score: 0.6782 - val_loss: 0.0540 - val_mse: 0.0540 - val_keras_r2_score: -0.0132
# Epoch 65/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.1322 - mse: 0.1322 - keras_r2_score: 0.6836 - val_loss: 0.0601 - val_mse: 0.0601 - val_keras_r2_score: -0.1216
# Epoch 66/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1237 - mse: 0.1237 - keras_r2_score: 0.6316 - val_loss: 0.0523 - val_mse: 0.0523 - val_keras_r2_score: 0.0615
# Epoch 67/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1396 - mse: 0.1396 - keras_r2_score: 0.7300 - val_loss: 0.0543 - val_mse: 0.0543 - val_keras_r2_score: -0.0011
# Epoch 68/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1152 - mse: 0.1152 - keras_r2_score: 0.8658 - val_loss: 0.0576 - val_mse: 0.0576 - val_keras_r2_score: -0.0732
# Epoch 69/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1230 - mse: 0.1230 - keras_r2_score: 0.7562 - val_loss: 0.0515 - val_mse: 0.0515 - val_keras_r2_score: 0.0479
# Epoch 70/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1070 - mse: 0.1070 - keras_r2_score: 0.7484 - val_loss: 0.0497 - val_mse: 0.0497 - val_keras_r2_score: 0.0925
# Epoch 71/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1403 - mse: 0.1403 - keras_r2_score: 0.8530 - val_loss: 0.0509 - val_mse: 0.0509 - val_keras_r2_score: 0.0544
# Epoch 72/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1199 - mse: 0.1199 - keras_r2_score: 0.7480 - val_loss: 0.0782 - val_mse: 0.0782 - val_keras_r2_score: -0.4365
# Epoch 73/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1421 - mse: 0.1421 - keras_r2_score: 0.7388 - val_loss: 0.0611 - val_mse: 0.0611 - val_keras_r2_score: -0.1267
# Epoch 74/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1212 - mse: 0.1212 - keras_r2_score: 0.7617 - val_loss: 0.0566 - val_mse: 0.0566 - val_keras_r2_score: -0.0312
# Epoch 75/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1073 - mse: 0.1073 - keras_r2_score: 0.8951 - val_loss: 0.0532 - val_mse: 0.0532 - val_keras_r2_score: 0.0288
# Epoch 76/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1212 - mse: 0.1212 - keras_r2_score: 0.8634 - val_loss: 0.0536 - val_mse: 0.0536 - val_keras_r2_score: 0.0166
# Epoch 77/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1106 - mse: 0.1106 - keras_r2_score: 0.2574 - val_loss: 0.0514 - val_mse: 0.0514 - val_keras_r2_score: 0.0435
# Epoch 78/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2365 - mse: 0.2365 - keras_r2_score: 0.6916 - val_loss: 0.0566 - val_mse: 0.0566 - val_keras_r2_score: -0.0597
# Epoch 79/1000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3264 - mse: 0.3264 - keras_r2_score: 0.5841 - val_loss: 0.0540 - val_mse: 0.0540 - val_keras_r2_score: 0.0076
# Epoch 80/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3577 - mse: 0.3577 - keras_r2_score: 0.5588 - val_loss: 0.0589 - val_mse: 0.0589 - val_keras_r2_score: -0.0900
# Epoch 81/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.3067 - mse: 0.3067 - keras_r2_score: 0.6178 - val_loss: 0.0605 - val_mse: 0.0605 - val_keras_r2_score: -0.1306
# Epoch 82/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2889 - mse: 0.2889 - keras_r2_score: 0.6228 - val_loss: 0.0611 - val_mse: 0.0611 - val_keras_r2_score: -0.1383
# Epoch 83/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3317 - mse: 0.3317 - keras_r2_score: 0.6526 - val_loss: 0.0597 - val_mse: 0.0597 - val_keras_r2_score: -0.1046
# Epoch 84/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3528 - mse: 0.3528 - keras_r2_score: 0.4826 - val_loss: 0.0712 - val_mse: 0.0712 - val_keras_r2_score: -0.2726
# Epoch 85/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3397 - mse: 0.3397 - keras_r2_score: 0.6846 - val_loss: 0.0680 - val_mse: 0.0680 - val_keras_r2_score: -0.2522
# Epoch 86/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.2772 - mse: 0.2772 - keras_r2_score: 0.6709 - val_loss: 0.0586 - val_mse: 0.0586 - val_keras_r2_score: -0.0659
# Epoch 87/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1933 - mse: 0.1933 - keras_r2_score: 0.2604 - val_loss: 0.0574 - val_mse: 0.0574 - val_keras_r2_score: -0.0523
# Epoch 88/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1804 - mse: 0.1804 - keras_r2_score: 0.6540 - val_loss: 0.0635 - val_mse: 0.0635 - val_keras_r2_score: -0.1681
# Epoch 89/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1223 - mse: 0.1223 - keras_r2_score: 0.8671 - val_loss: 0.0638 - val_mse: 0.0638 - val_keras_r2_score: -0.2078
# Epoch 90/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1198 - mse: 0.1198 - keras_r2_score: 0.6667 - val_loss: 0.0554 - val_mse: 0.0554 - val_keras_r2_score: -0.0320
# Epoch 91/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1115 - mse: 0.1115 - keras_r2_score: 0.7428 - val_loss: 0.0549 - val_mse: 0.0549 - val_keras_r2_score: -0.0188
# Epoch 92/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1127 - mse: 0.1127 - keras_r2_score: 0.7700 - val_loss: 0.0623 - val_mse: 0.0623 - val_keras_r2_score: -0.1796
# Epoch 93/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1035 - mse: 0.1035 - keras_r2_score: 0.7713 - val_loss: 0.0567 - val_mse: 0.0567 - val_keras_r2_score: -0.0602
# Epoch 94/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1133 - mse: 0.1133 - keras_r2_score: 0.8777 - val_loss: 0.0536 - val_mse: 0.0536 - val_keras_r2_score: 0.0179
# Epoch 95/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1036 - mse: 0.1036 - keras_r2_score: 0.8821 - val_loss: 0.0513 - val_mse: 0.0513 - val_keras_r2_score: 0.0469
# Epoch 96/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1080 - mse: 0.1080 - keras_r2_score: 0.7926 - val_loss: 0.0547 - val_mse: 0.0547 - val_keras_r2_score: -0.0151
# Epoch 97/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1376 - mse: 0.1376 - keras_r2_score: 0.7417 - val_loss: 0.0527 - val_mse: 0.0527 - val_keras_r2_score: 0.0254
# Epoch 98/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1149 - mse: 0.1149 - keras_r2_score: 0.7525 - val_loss: 0.0539 - val_mse: 0.0539 - val_keras_r2_score: 0.0061
# Epoch 99/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1062 - mse: 0.1062 - keras_r2_score: 0.8980 - val_loss: 0.0549 - val_mse: 0.0549 - val_keras_r2_score: -0.0218
# Epoch 100/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0987 - mse: 0.0987 - keras_r2_score: 0.7567 - val_loss: 0.0562 - val_mse: 0.0562 - val_keras_r2_score: -0.0565
# Epoch 101/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0996 - mse: 0.0996 - keras_r2_score: 0.8557 - val_loss: 0.0564 - val_mse: 0.0564 - val_keras_r2_score: -0.0601
# Epoch 102/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0979 - mse: 0.0979 - keras_r2_score: 0.7214 - val_loss: 0.0532 - val_mse: 0.0532 - val_keras_r2_score: 0.0052
# Epoch 103/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1013 - mse: 0.1013 - keras_r2_score: 0.7293 - val_loss: 0.0565 - val_mse: 0.0565 - val_keras_r2_score: -0.0571
# Epoch 104/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0998 - mse: 0.0998 - keras_r2_score: 0.7724 - val_loss: 0.0581 - val_mse: 0.0581 - val_keras_r2_score: -0.0870
# Epoch 105/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0989 - mse: 0.0989 - keras_r2_score: 0.8357 - val_loss: 0.0531 - val_mse: 0.0531 - val_keras_r2_score: 0.0216
# Epoch 106/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1122 - mse: 0.1122 - keras_r2_score: 0.6002 - val_loss: 0.0517 - val_mse: 0.0517 - val_keras_r2_score: 0.0440
# Epoch 107/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0939 - mse: 0.0939 - keras_r2_score: 0.8208 - val_loss: 0.0521 - val_mse: 0.0521 - val_keras_r2_score: 0.0319
# Epoch 108/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0995 - mse: 0.0995 - keras_r2_score: 0.7996 - val_loss: 0.0515 - val_mse: 0.0515 - val_keras_r2_score: 0.0552
# Epoch 109/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0999 - mse: 0.0999 - keras_r2_score: 0.5823 - val_loss: 0.0528 - val_mse: 0.0528 - val_keras_r2_score: 0.0199
# Epoch 110/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0911 - mse: 0.0911 - keras_r2_score: 0.7397 - val_loss: 0.0556 - val_mse: 0.0556 - val_keras_r2_score: -0.0376
# Epoch 111/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1048 - mse: 0.1048 - keras_r2_score: 0.8773 - val_loss: 0.0533 - val_mse: 0.0533 - val_keras_r2_score: 0.0136
# Epoch 112/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0950 - mse: 0.0950 - keras_r2_score: 0.8083 - val_loss: 0.0508 - val_mse: 0.0508 - val_keras_r2_score: 0.0613
# Epoch 113/1000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0946 - mse: 0.0946 - keras_r2_score: 0.8164 - val_loss: 0.0524 - val_mse: 0.0524 - val_keras_r2_score: 0.0282
# Epoch 114/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1012 - mse: 0.1012 - keras_r2_score: 0.7917 - val_loss: 0.0540 - val_mse: 0.0540 - val_keras_r2_score: 0.0054
# Epoch 115/1000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.1079 - mse: 0.1079 - keras_r2_score: 0.7464 - val_loss: 0.0533 - val_mse: 0.0533 - val_keras_r2_score: 0.0054
# Epoch 116/1000
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0996 - mse: 0.0996 - keras_r2_score: 0.8311 - val_loss: 0.0533 - val_mse: 0.0533 - val_keras_r2_score: 0.0140
# Epoch 117/1000
# 7/7 [==============================] - 1s 87ms/step - loss: 0.1055 - mse: 0.1055 - keras_r2_score: 0.8085 - val_loss: 0.0531 - val_mse: 0.0531 - val_keras_r2_score: 0.0177
# Epoch 118/1000
# 7/7 [==============================] - 1s 75ms/step - loss: 0.1064 - mse: 0.1064 - keras_r2_score: 0.7998 - val_loss: 0.0621 - val_mse: 0.0621 - val_keras_r2_score: -0.1742
# Epoch 119/1000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0984 - mse: 0.0984 - keras_r2_score: 0.6331 - val_loss: 0.0608 - val_mse: 0.0608 - val_keras_r2_score: -0.1429
# Epoch 120/1000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0939 - mse: 0.0939 - keras_r2_score: 0.7949 - val_loss: 0.0544 - val_mse: 0.0544 - val_keras_r2_score: -0.0115
# Epoch 121/1000
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0887 - mse: 0.0887 - keras_r2_score: 0.8181 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0751
# Epoch 122/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0923 - mse: 0.0923 - keras_r2_score: 0.7029 - val_loss: 0.0535 - val_mse: 0.0535 - val_keras_r2_score: 0.0132
# Epoch 123/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0913 - mse: 0.0913 - keras_r2_score: 0.8959 - val_loss: 0.0536 - val_mse: 0.0536 - val_keras_r2_score: 0.0144
# Epoch 124/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0927 - mse: 0.0927 - keras_r2_score: 0.8216 - val_loss: 0.0510 - val_mse: 0.0510 - val_keras_r2_score: 0.0584
# Epoch 125/1000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0911 - mse: 0.0911 - keras_r2_score: 0.7721 - val_loss: 0.0551 - val_mse: 0.0551 - val_keras_r2_score: -0.0261
# Epoch 126/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0870 - mse: 0.0870 - keras_r2_score: 0.8385 - val_loss: 0.0544 - val_mse: 0.0544 - val_keras_r2_score: -0.0228
# Epoch 127/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0889 - mse: 0.0889 - keras_r2_score: 0.7859 - val_loss: 0.0525 - val_mse: 0.0525 - val_keras_r2_score: 0.0291
# Epoch 128/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0931 - mse: 0.0931 - keras_r2_score: 0.6528 - val_loss: 0.0564 - val_mse: 0.0564 - val_keras_r2_score: -0.0514
# Epoch 129/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0877 - mse: 0.0877 - keras_r2_score: 0.8128 - val_loss: 0.0557 - val_mse: 0.0557 - val_keras_r2_score: -0.0366
# Epoch 130/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0883 - mse: 0.0883 - keras_r2_score: 0.9099 - val_loss: 0.0586 - val_mse: 0.0586 - val_keras_r2_score: -0.1026
# Epoch 131/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0925 - mse: 0.0925 - keras_r2_score: 0.7429 - val_loss: 0.0547 - val_mse: 0.0547 - val_keras_r2_score: -0.0296
# Epoch 132/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0941 - mse: 0.0941 - keras_r2_score: 0.7949 - val_loss: 0.0532 - val_mse: 0.0532 - val_keras_r2_score: -0.0080
# Epoch 133/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0975 - mse: 0.0975 - keras_r2_score: 0.6904 - val_loss: 0.0540 - val_mse: 0.0540 - val_keras_r2_score: -0.0215
# Epoch 134/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0912 - mse: 0.0912 - keras_r2_score: 0.8945 - val_loss: 0.0542 - val_mse: 0.0542 - val_keras_r2_score: -0.0152
# Epoch 135/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0915 - mse: 0.0915 - keras_r2_score: 0.9091 - val_loss: 0.0578 - val_mse: 0.0578 - val_keras_r2_score: -0.0846
# Epoch 136/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0927 - mse: 0.0927 - keras_r2_score: 0.8871 - val_loss: 0.0579 - val_mse: 0.0579 - val_keras_r2_score: -0.0762
# Epoch 137/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0931 - mse: 0.0931 - keras_r2_score: 0.6704 - val_loss: 0.0583 - val_mse: 0.0583 - val_keras_r2_score: -0.0883
# Epoch 138/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1034 - mse: 0.1034 - keras_r2_score: 0.8795 - val_loss: 0.0535 - val_mse: 0.0535 - val_keras_r2_score: 0.0044
# Epoch 139/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0963 - mse: 0.0963 - keras_r2_score: 0.7844 - val_loss: 0.0556 - val_mse: 0.0556 - val_keras_r2_score: -0.0269
# Epoch 140/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0989 - mse: 0.0989 - keras_r2_score: 0.8759 - val_loss: 0.0555 - val_mse: 0.0555 - val_keras_r2_score: -0.0361
# Epoch 141/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0966 - mse: 0.0966 - keras_r2_score: 0.8137 - val_loss: 0.0538 - val_mse: 0.0538 - val_keras_r2_score: 0.0027
# Epoch 142/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0875 - mse: 0.0875 - keras_r2_score: 0.6673 - val_loss: 0.0522 - val_mse: 0.0522 - val_keras_r2_score: 0.0408
# Epoch 143/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0916 - mse: 0.0916 - keras_r2_score: 0.8776 - val_loss: 0.0567 - val_mse: 0.0567 - val_keras_r2_score: -0.0755
# Epoch 144/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0903 - mse: 0.0903 - keras_r2_score: 0.7739 - val_loss: 0.0580 - val_mse: 0.0580 - val_keras_r2_score: -0.0963
# Epoch 145/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0887 - mse: 0.0887 - keras_r2_score: 0.7742 - val_loss: 0.0553 - val_mse: 0.0553 - val_keras_r2_score: -0.0290
# Epoch 146/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0942 - mse: 0.0942 - keras_r2_score: 0.7326 - val_loss: 0.0607 - val_mse: 0.0607 - val_keras_r2_score: -0.1475
# Epoch 147/1000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0899 - mse: 0.0899 - keras_r2_score: 0.7466 - val_loss: 0.0615 - val_mse: 0.0615 - val_keras_r2_score: -0.1636
# Epoch 148/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0898 - mse: 0.0898 - keras_r2_score: 0.8447 - val_loss: 0.0550 - val_mse: 0.0550 - val_keras_r2_score: -0.0259
# Epoch 149/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0869 - mse: 0.0869 - keras_r2_score: 0.6970 - val_loss: 0.0536 - val_mse: 0.0536 - val_keras_r2_score: -0.0119
# Epoch 150/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0865 - mse: 0.0865 - keras_r2_score: 0.8694 - val_loss: 0.0523 - val_mse: 0.0523 - val_keras_r2_score: 0.0097
# Epoch 151/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0889 - mse: 0.0889 - keras_r2_score: 0.8901 - val_loss: 0.0563 - val_mse: 0.0563 - val_keras_r2_score: -0.0576
# Epoch 152/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1013 - mse: 0.1013 - keras_r2_score: 0.8320 - val_loss: 0.0585 - val_mse: 0.0585 - val_keras_r2_score: -0.1073
# Epoch 153/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0928 - mse: 0.0928 - keras_r2_score: 0.8913 - val_loss: 0.0580 - val_mse: 0.0580 - val_keras_r2_score: -0.0721
# Epoch 154/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1147 - mse: 0.1147 - keras_r2_score: 0.3338 - val_loss: 0.0714 - val_mse: 0.0714 - val_keras_r2_score: -0.3401
# Epoch 155/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3040 - mse: 0.3040 - keras_r2_score: 0.6277 - val_loss: 0.0631 - val_mse: 0.0631 - val_keras_r2_score: -0.1703
# Epoch 156/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.2492 - mse: 0.2492 - keras_r2_score: 0.3766 - val_loss: 0.0658 - val_mse: 0.0658 - val_keras_r2_score: -0.1997
# Epoch 157/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1649 - mse: 0.1649 - keras_r2_score: 0.8293 - val_loss: 0.0641 - val_mse: 0.0641 - val_keras_r2_score: -0.1908
# Epoch 158/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1297 - mse: 0.1297 - keras_r2_score: 0.8440 - val_loss: 0.0591 - val_mse: 0.0591 - val_keras_r2_score: -0.1107
# Epoch 159/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1145 - mse: 0.1145 - keras_r2_score: 0.8615 - val_loss: 0.0593 - val_mse: 0.0593 - val_keras_r2_score: -0.0994
# Epoch 160/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1089 - mse: 0.1089 - keras_r2_score: 0.8438 - val_loss: 0.0602 - val_mse: 0.0602 - val_keras_r2_score: -0.1300
# Epoch 161/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1169 - mse: 0.1169 - keras_r2_score: 0.7734 - val_loss: 0.0519 - val_mse: 0.0519 - val_keras_r2_score: 0.0411
# Epoch 162/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1007 - mse: 0.1007 - keras_r2_score: 0.8824 - val_loss: 0.0523 - val_mse: 0.0523 - val_keras_r2_score: 0.0524
# Epoch 163/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0956 - mse: 0.0956 - keras_r2_score: 0.7964 - val_loss: 0.0566 - val_mse: 0.0566 - val_keras_r2_score: -0.0633
# Epoch 164/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1021 - mse: 0.1021 - keras_r2_score: 0.7092 - val_loss: 0.0592 - val_mse: 0.0592 - val_keras_r2_score: -0.1072
# Epoch 165/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1059 - mse: 0.1059 - keras_r2_score: 0.8763 - val_loss: 0.0527 - val_mse: 0.0527 - val_keras_r2_score: 0.0314
# Epoch 166/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0943 - mse: 0.0943 - keras_r2_score: 0.9056 - val_loss: 0.0517 - val_mse: 0.0517 - val_keras_r2_score: 0.0542
# Epoch 167/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1056 - mse: 0.1056 - keras_r2_score: 0.8700 - val_loss: 0.0530 - val_mse: 0.0530 - val_keras_r2_score: 0.0150
# Epoch 168/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1051 - mse: 0.1051 - keras_r2_score: 0.8161 - val_loss: 0.0538 - val_mse: 0.0538 - val_keras_r2_score: -0.0034
# Epoch 169/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1081 - mse: 0.1081 - keras_r2_score: 0.7854 - val_loss: 0.0528 - val_mse: 0.0528 - val_keras_r2_score: 0.0275
# Epoch 170/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1700 - mse: 0.1700 - keras_r2_score: 0.7795 - val_loss: 0.0537 - val_mse: 0.0537 - val_keras_r2_score: 0.0108
# Epoch 171/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1343 - mse: 0.1343 - keras_r2_score: 0.7382 - val_loss: 0.0534 - val_mse: 0.0534 - val_keras_r2_score: 0.0231
# Epoch 172/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0979 - mse: 0.0979 - keras_r2_score: 0.8173 - val_loss: 0.0550 - val_mse: 0.0550 - val_keras_r2_score: -0.0154
# Epoch 173/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0983 - mse: 0.0983 - keras_r2_score: 0.6266 - val_loss: 0.0577 - val_mse: 0.0577 - val_keras_r2_score: -0.0856
# Epoch 174/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1001 - mse: 0.1001 - keras_r2_score: 0.7809 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0695
# Epoch 175/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1364 - mse: 0.1364 - keras_r2_score: 0.8606 - val_loss: 0.0529 - val_mse: 0.0529 - val_keras_r2_score: 0.0374
# Epoch 176/1000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.1265 - mse: 0.1265 - keras_r2_score: 0.8670 - val_loss: 0.0542 - val_mse: 0.0542 - val_keras_r2_score: -0.0115
# Epoch 177/1000
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1096 - mse: 0.1096 - keras_r2_score: 0.8848 - val_loss: 0.0593 - val_mse: 0.0593 - val_keras_r2_score: -0.1191
# Epoch 178/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0938 - mse: 0.0938 - keras_r2_score: 0.8472 - val_loss: 0.0525 - val_mse: 0.0525 - val_keras_r2_score: 0.0038
# Epoch 179/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1027 - mse: 0.1027 - keras_r2_score: 0.8206 - val_loss: 0.0570 - val_mse: 0.0570 - val_keras_r2_score: -0.0813
# Epoch 180/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0940 - mse: 0.0940 - keras_r2_score: 0.7885 - val_loss: 0.0518 - val_mse: 0.0518 - val_keras_r2_score: 0.0271
# Epoch 181/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0909 - mse: 0.0909 - keras_r2_score: 0.7798 - val_loss: 0.0529 - val_mse: 0.0529 - val_keras_r2_score: 0.0182
# Epoch 182/1000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0893 - mse: 0.0893 - keras_r2_score: 0.8859 - val_loss: 0.0509 - val_mse: 0.0509 - val_keras_r2_score: 0.0570
# Epoch 183/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0845 - mse: 0.0845 - keras_r2_score: 0.7566 - val_loss: 0.0507 - val_mse: 0.0507 - val_keras_r2_score: 0.0547
# Epoch 184/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0833 - mse: 0.0833 - keras_r2_score: 0.9080 - val_loss: 0.0506 - val_mse: 0.0506 - val_keras_r2_score: 0.0601
# Epoch 185/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0867 - mse: 0.0867 - keras_r2_score: 0.7897 - val_loss: 0.0531 - val_mse: 0.0531 - val_keras_r2_score: 0.0015
# Epoch 186/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0844 - mse: 0.0844 - keras_r2_score: 0.7559 - val_loss: 0.0497 - val_mse: 0.0497 - val_keras_r2_score: 0.0640
# Epoch 187/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0878 - mse: 0.0878 - keras_r2_score: 0.9011 - val_loss: 0.0508 - val_mse: 0.0508 - val_keras_r2_score: 0.0446
# Epoch 188/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0977 - mse: 0.0977 - keras_r2_score: 0.7449 - val_loss: 0.0537 - val_mse: 0.0537 - val_keras_r2_score: -0.0013
# Epoch 189/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0888 - mse: 0.0888 - keras_r2_score: 0.7796 - val_loss: 0.0521 - val_mse: 0.0521 - val_keras_r2_score: 0.0276
# Epoch 190/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0892 - mse: 0.0892 - keras_r2_score: 0.9041 - val_loss: 0.0498 - val_mse: 0.0498 - val_keras_r2_score: 0.0628
# Epoch 191/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0856 - mse: 0.0856 - keras_r2_score: 0.8004 - val_loss: 0.0481 - val_mse: 0.0481 - val_keras_r2_score: 0.0954
# Epoch 192/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0939 - mse: 0.0939 - keras_r2_score: 0.6057 - val_loss: 0.0491 - val_mse: 0.0491 - val_keras_r2_score: 0.0720
# Epoch 193/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0848 - mse: 0.0848 - keras_r2_score: 0.8874 - val_loss: 0.0497 - val_mse: 0.0497 - val_keras_r2_score: 0.0663
# Epoch 194/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0872 - mse: 0.0872 - keras_r2_score: 0.8787 - val_loss: 0.0511 - val_mse: 0.0511 - val_keras_r2_score: 0.0439
# Epoch 195/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1071 - mse: 0.1071 - keras_r2_score: 0.7364 - val_loss: 0.0526 - val_mse: 0.0526 - val_keras_r2_score: 0.0233
# Epoch 196/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2594 - mse: 0.2594 - keras_r2_score: 0.6408 - val_loss: 0.0542 - val_mse: 0.0542 - val_keras_r2_score: -0.0023
# Epoch 197/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1509 - mse: 0.1509 - keras_r2_score: 0.8178 - val_loss: 0.0600 - val_mse: 0.0600 - val_keras_r2_score: -0.1194
# Epoch 198/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2541 - mse: 0.2541 - keras_r2_score: 0.5575 - val_loss: 0.0613 - val_mse: 0.0613 - val_keras_r2_score: -0.1578
# Epoch 199/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2223 - mse: 0.2223 - keras_r2_score: 0.7661 - val_loss: 0.0619 - val_mse: 0.0619 - val_keras_r2_score: -0.1820
# Epoch 200/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1291 - mse: 0.1291 - keras_r2_score: 0.7755 - val_loss: 0.0598 - val_mse: 0.0598 - val_keras_r2_score: -0.1255
# Epoch 201/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1239 - mse: 0.1239 - keras_r2_score: 0.6810 - val_loss: 0.0589 - val_mse: 0.0589 - val_keras_r2_score: -0.1227
# Epoch 202/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1033 - mse: 0.1033 - keras_r2_score: 0.5839 - val_loss: 0.0623 - val_mse: 0.0623 - val_keras_r2_score: -0.1871
# Epoch 203/1000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.1273 - mse: 0.1273 - keras_r2_score: 0.6723 - val_loss: 0.0545 - val_mse: 0.0545 - val_keras_r2_score: -0.0234
# Epoch 204/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1317 - mse: 0.1317 - keras_r2_score: 0.7632 - val_loss: 0.0543 - val_mse: 0.0543 - val_keras_r2_score: -0.0228
# Epoch 205/1000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.1637 - mse: 0.1637 - keras_r2_score: -0.3450 - val_loss: 0.0547 - val_mse: 0.0547 - val_keras_r2_score: -0.0363
# Epoch 206/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1158 - mse: 0.1158 - keras_r2_score: 0.6394 - val_loss: 0.0581 - val_mse: 0.0581 - val_keras_r2_score: -0.0926
# Epoch 207/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.2729 - mse: 0.2729 - keras_r2_score: 0.6774 - val_loss: 0.0741 - val_mse: 0.0741 - val_keras_r2_score: -0.3886
# Epoch 208/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1580 - mse: 0.1580 - keras_r2_score: 0.6681 - val_loss: 0.0713 - val_mse: 0.0713 - val_keras_r2_score: -0.3383
# Epoch 209/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1981 - mse: 0.1981 - keras_r2_score: 0.3331 - val_loss: 0.0809 - val_mse: 0.0809 - val_keras_r2_score: -0.5560
# Epoch 210/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.2056 - mse: 0.2056 - keras_r2_score: 0.7785 - val_loss: 0.0583 - val_mse: 0.0583 - val_keras_r2_score: -0.0973
# Epoch 211/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1689 - mse: 0.1689 - keras_r2_score: 0.7595 - val_loss: 0.0507 - val_mse: 0.0507 - val_keras_r2_score: 0.0582
# Epoch 212/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1725 - mse: 0.1725 - keras_r2_score: 0.7505 - val_loss: 0.0550 - val_mse: 0.0550 - val_keras_r2_score: -0.0190
# Epoch 213/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1386 - mse: 0.1386 - keras_r2_score: 0.7805 - val_loss: 0.0693 - val_mse: 0.0693 - val_keras_r2_score: -0.3059
# Epoch 214/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1592 - mse: 0.1592 - keras_r2_score: 0.5639 - val_loss: 0.0633 - val_mse: 0.0633 - val_keras_r2_score: -0.1792
# Epoch 215/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1342 - mse: 0.1342 - keras_r2_score: 0.5793 - val_loss: 0.0678 - val_mse: 0.0678 - val_keras_r2_score: -0.2848
# Epoch 216/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1856 - mse: 0.1856 - keras_r2_score: 0.7662 - val_loss: 0.0556 - val_mse: 0.0556 - val_keras_r2_score: -0.0521
# Epoch 217/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1543 - mse: 0.1543 - keras_r2_score: 0.8288 - val_loss: 0.0528 - val_mse: 0.0528 - val_keras_r2_score: 0.0339
# Epoch 218/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1696 - mse: 0.1696 - keras_r2_score: 0.5676 - val_loss: 0.0566 - val_mse: 0.0566 - val_keras_r2_score: -0.0451
# Epoch 219/1000
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1532 - mse: 0.1532 - keras_r2_score: 0.8277 - val_loss: 0.0562 - val_mse: 0.0562 - val_keras_r2_score: -0.0424
# Epoch 220/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1488 - mse: 0.1488 - keras_r2_score: 0.8359 - val_loss: 0.0546 - val_mse: 0.0546 - val_keras_r2_score: -0.0097
# Epoch 221/1000
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1592 - mse: 0.1592 - keras_r2_score: 0.7734 - val_loss: 0.0549 - val_mse: 0.0549 - val_keras_r2_score: 0.0039
# Epoch 222/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1467 - mse: 0.1467 - keras_r2_score: 0.6401 - val_loss: 0.0570 - val_mse: 0.0570 - val_keras_r2_score: -0.0476
# Epoch 223/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1354 - mse: 0.1354 - keras_r2_score: 0.6258 - val_loss: 0.0575 - val_mse: 0.0575 - val_keras_r2_score: -0.0651
# Epoch 224/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1346 - mse: 0.1346 - keras_r2_score: 0.7280 - val_loss: 0.0599 - val_mse: 0.0599 - val_keras_r2_score: -0.1327
# Epoch 225/1000
# 7/7 [==============================] - 0s 57ms/step - loss: 0.1312 - mse: 0.1312 - keras_r2_score: 0.7697 - val_loss: 0.0626 - val_mse: 0.0626 - val_keras_r2_score: -0.1943
# Epoch 226/1000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1308 - mse: 0.1308 - keras_r2_score: 0.8566 - val_loss: 0.0632 - val_mse: 0.0632 - val_keras_r2_score: -0.1850
# Epoch 227/1000
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1264 - mse: 0.1264 - keras_r2_score: 0.6486 - val_loss: 0.0665 - val_mse: 0.0665 - val_keras_r2_score: -0.2269
# Epoch 228/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1189 - mse: 0.1189 - keras_r2_score: 0.7277 - val_loss: 0.0626 - val_mse: 0.0626 - val_keras_r2_score: -0.1652
# Epoch 229/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1145 - mse: 0.1145 - keras_r2_score: 0.7980 - val_loss: 0.0534 - val_mse: 0.0534 - val_keras_r2_score: 0.0143
# Epoch 230/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1157 - mse: 0.1157 - keras_r2_score: 0.5068 - val_loss: 0.0559 - val_mse: 0.0559 - val_keras_r2_score: -0.0470
# Epoch 231/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1068 - mse: 0.1068 - keras_r2_score: 0.7719 - val_loss: 0.0613 - val_mse: 0.0613 - val_keras_r2_score: -0.1602
# Epoch 232/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1079 - mse: 0.1079 - keras_r2_score: 0.8798 - val_loss: 0.0577 - val_mse: 0.0577 - val_keras_r2_score: -0.1036
# Epoch 233/1000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.1144 - mse: 0.1144 - keras_r2_score: 0.8747 - val_loss: 0.0654 - val_mse: 0.0654 - val_keras_r2_score: -0.2357

# %%
# 画结果图
def plot(data,mode="all"):
    if mode == "all":
        test_data = data
    elif mode == "train":
        test_data = data.iloc[:int(0.8 * len(data)),:]
    elif mode == "test":
        test_data = data.iloc[int(0.8 * len(data)):,:]
    test_features = test_data.loc[:,feature_cols].values
    test_targets = test_data.loc[:,target_col].values[:,np.newaxis]
    pred = model.predict(scaler.transform(test_features)[:,np.newaxis,:])
    true = y_scaler.transform(test_targets)
    pred = y_scaler.inverse_transform(pred)
    true = y_scaler.inverse_transform(true)
    print(r2_score(true,pred))
    plt.figure(figsize=(6,3))
    plt.plot(true,label="true value")
    plt.plot(pred,label="pred value")
    plt.legend()
    plt.savefig('pre.svg',format='svg',dpi=150)
    plt.show()

# %%
fig = plot(data,mode="test")
# Out:
# 0.14026851935779883

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.41.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.5.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)

# %%
# 定义模型的预测方式
import shap
def f(X):
    # return model.predict([X[:,i] for i in range(X.shape[1])]).flatten()
    return model.predict(np.expand_dims(X, 1)).flatten()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-72399a523181> in <module>
#       1 # 定义模型的预测方式
# ----> 2 import shap
#       3 def f(X):
#       4     # return model.predict([X[:,i] for i in range(X.shape[1])]).flatten()
#       5     return model.predict(np.expand_dims(X, 1)).flatten()
#
# /usr/local/lib/python3.7/dist-packages/shap/__init__.py in <module>
#      13
#      14 # explainers
# ---> 15 from .explainers._explainer import Explainer
#      16 from .explainers._kernel import Kernel as KernelExplainer
#      17 from .explainers._sampling import Sampling as SamplingExplainer
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/__init__.py in <module>
# ----> 1 from ._permutation import Permutation
#       2 from ._partition import Partition
#       3 from ._tree import Tree
#       4 from ._gpu_tree import GPUTree
#       5 from ._exact import Exact
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_permutation.py in <module>
#       3 from ..utils import partition_tree_shuffle, MaskedModel
#       4 from .._explanation import Explanation
# ----> 5 from ._explainer import Explainer
#       6 import numpy as np
#       7 import pandas as pd
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_explainer.py in <module>
#       3 import numpy as np
#       4 import scipy as sp
# ----> 5 from .. import maskers
#       6 from .. import links
#       7 from ..utils import safe_isinstance, show_progress
#
# /usr/local/lib/python3.7/dist-packages/shap/maskers/__init__.py in <module>
#       1 from ._masker import Masker
#       2 from ._tabular import Independent, Partition, Impute
# ----> 3 from ._image import Image
#       4 from ._text import Text
#       5 from ._fixed import Fixed
#
# /usr/local/lib/python3.7/dist-packages/shap/maskers/_image.py in <module>
#       7 from numba import jit
#       8 try:
# ----> 9     import torch
#      10 except ImportError as e:
#      11     record_import_error("torch", "torch could not be imported!", e)
#
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py in <module>
#     200     if USE_GLOBAL_DEPS:
#     201         _load_global_deps()
# --> 202     from torch._C import *  # noqa: F403
#     203
#     204 # Appease the type checker; ordinarily this binding is inserted by the
#
# ValueError: module functions cannot set METH_CLASS or METH_STATIC

# %%
# 计算对应的shap值
features = scaler.transform(features)
input_X = features
explainer = shap.KernelExplainer(f, input_X.squeeze())
shap_values = explainer.shap_values(input_X, nsamples=500)

# %%
import matplotlib.pyplot as plt

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values,data.loc[:,feature_cols])
#fig = shap.force_plot(explainer.expected_value, shap_values,data.loc[:,feature_cols])
#shap.plots.force(explainer.expected_value, shap_values,data.loc[:,feature_cols], show=False, matplotlib=True).savefig('shap1.svg')
#plt.savefig('shap.svg',format='svg',dpi=1000)

# %%
shap.initjs()
fig = shap.summary_plot(shap_values, data.loc[:,feature_cols], plot_type='bar', show=False)
plt.savefig('shap.svg',format='svg',dpi=150)

# %%
shap.initjs()
fig = shap.summary_plot(shap_values, data.loc[:,feature_cols], show=False)
plt.savefig('shap2.svg',format='svg',dpi=150)

# %%
shap.initjs()
shap.dependence_plot("Fri", shap_values, data.loc[:,feature_cols])
